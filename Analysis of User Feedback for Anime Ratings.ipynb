# %%
#Unveiling the Anime Odyssey.

# %%
#--- Import Pandas ---
import pandas as pd
#--- Read in dataset ----
df = pd.read_csv('./animee.csv')


df
# Out:
#        Unnamed: 0                                              Title  \
# 0               0         Kaguya-sama wa Kokurasetai: Ultra Romantic
# 1               1                         3-gatsu no Lion 2nd Season
# 2               2  Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...
# 3               3                                           Gintama.
# 4               4                                     Koe no Katachi
# ...           ...                                                ...
# 20338       20338                                        Steins;Gate
# 20339       20339                                         High Score
# 20340       20340                                           Noraneko
# 20341       20341             Suki de Suki de, Suki de The Animation
# 20342       20342                            Koihime†Musou OVA Omake
#
#                                Genres   Rank  Popularity  Score Episodes  \
# ...

# %%
# Navigating the Data Abyss
null_values = df.isnull().sum()

null_values
# Out:
# Title                 0
# Genres            10327
# Rank                  0
# Popularity            0
# Score              6324
# Episodes              0
# Episode length        0
# Release Date      15256
# dtype: int64

# %%
#---  Refining the Anime Constellation
df['Genres'] = df['Genres'].fillna(method='ffill')
mean_score = round(df['Score'].mean(), 2)
df['Score'] = df['Score'].fillna(mean_score)
df['Release Date'] = df['Release Date'].fillna(method='ffill')
df
# Out:
#                                                    Title  \
# 0             Kaguya-sama wa Kokurasetai: Ultra Romantic
# 1                             3-gatsu no Lion 2nd Season
# 2      Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...
# 3                                               Gintama.
# 4                                         Koe no Katachi
# ...                                                  ...
# 20338                                        Steins;Gate
# 20339                                         High Score
# 20340                                           Noraneko
# 20341             Suki de Suki de, Suki de The Animation
# 20342                            Koihime†Musou OVA Omake
#
#                                Genres   Rank  Popularity  Score Episodes  \
# 0                     Comedy,Suspense     13         404   8.99       12
# 1                 Drama,Slice of Life     14         533   8.96       22
# ...

# %%
# Preserving the Anime Chronicles
#export the cleaned data
#df.to_csv('animee.csv',index='False')


df
# Out:
#                                                    Title  \
# 0             Kaguya-sama wa Kokurasetai: Ultra Romantic
# 1                             3-gatsu no Lion 2nd Season
# 2      Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...
# 3                                               Gintama.
# 4                                         Koe no Katachi
# ...                                                  ...
# 20338                                        Steins;Gate
# 20339                                         High Score
# 20340                                           Noraneko
# 20341             Suki de Suki de, Suki de The Animation
# 20342                            Koihime†Musou OVA Omake
#
#                                Genres   Rank  Popularity  Score Episodes  \
# 0                     Comedy,Suspense     13         404   8.99       12
# 1                 Drama,Slice of Life     14         533   8.96       22
# ...

# %%
# Data Download, Import, and Database Connection.
import pymysql
db_name = "animee"
db_host = "127.0.0.1"
db_username = "roof"
db_password = "root12"

try:
    conn = pymysql.connect(host = db_host,
                           port = int(3306),
                           user = "root",
                           password = db_password,
                           db = db_name)
except e:
    print (e)
if conn:
    print ("connection successful")
else:
        print ("error")
# Out:
# connection successful

# %%
import sqlite3 as sql

# %%
conn = sql.connect('animee.db')

# %%
# Counting the Anime Stars

# %%
query = 'select * from animee'
new_df = pd.read_sql(query, conn)
new_df.head(3)
# Out:
#    index                                              Title  \
# 0      0         Kaguya-sama wa Kokurasetai: Ultra Romantic
# 1      1                         3-gatsu no Lion 2nd Season
# 2      2  Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...
#
#                  Genres Rank  Popularity  Score Episodes   Episode length  \
# 0       Comedy,Suspense   13         404   8.99       12  23 min. per ep.
# 1   Drama,Slice of Life   14         533   8.96       22  25 min. per ep.
# 2  Action,Comedy,Sci-Fi   19         939   8.93        1    1 hr. 50 min.
#
#   Release Date
# 0  Spring 2022
# 1    Fall 2017
# 2    Fall 2017

# %%
#The Quest for Anime Excellence
query = '''select title , `rank` , score from animee
order by score desc limit 10'''

# %%
#Spotlight on Anime Singularities
query = '''select title, score , episodes from animee where episodes = 1 order by 
score desc limit 10'''

# %%
#Championing Multi-Episode Marvels
query = '''select title , score , episodes from animee  where episodes != 1 order by score 
desc limit 10'''

# %%
#Exploring the Anime Frontrunner
query = '''select title , popularity , score from animee where score != 1 
order by popularity desc limit 10'''

# %%
#Celebrating Short-Form Anime Brilliance
query = '''select title , popularity , score, episodes from animee where episodes = 1 AND
score != 0 order by popularity desc limit 10'''

# %%
#Elevating Multi-Episode Anime Excellence
query = '''Select title , popularity , score , episodes from animee where 
episodes > 1 AND score != 0  order by popularity desc limit 10'''

# %%
#Spotlighting Anime's Unique Zero-Episode Marvels
query = '''Select title , score , episodes from animee where episodes = 0 OR 'Unknown'
order by score desc limit 10'''

# %%
#Exploring Comedy in Extended Anime Narratives
query = '''Select title , score , episodes , genres from animee where episodes != 1
AND genres like '%Comedy%' order by score desc limit 10'''

# %%
# Quest for Anime's Pinnacle
query = '''select title , (score) as top_score  from animee where score in (Select max(score) from animee)'''

# %%
#Unveiling Anime's Hidden Gems
query = '''Select title , (score)as lowest_score from animee where score in (Select min(score)from animee)'''

# %%
#Unraveling the Tapestry of Multi-Episode Anime
query = '''select episodes , count(title)as no_of_animes from animee where episodes > 1 group by 
episodes order by no_of_animes desc limit 10'''
